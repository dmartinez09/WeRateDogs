# %% [markdown]
# ## Data Analysis and Visualization

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# >  This data analysis its about the WeRateDogs, a particular account of twitter community and based on the information provided by this account and Twitter. This account rates every dog on it.

# %% [markdown]
# ### Most common dog's breed
#
# The WeRateDogs community have a lot of post with dogs who represent a huge variety of different breed of dogs all of them are interesting but the data conclude the breed of dog with most rating and lower rating.
# <ul>
#     <li>The most common breed of dog was Golden Retriever, this breed of dog was the most rated on Twitter and the community WeRateDogs with more than 140 of ratings.</li>
#     <li>On the other hand Cocker Spaniel was the less rating with French Bulldogs with less of 20 ratings</li>
#     </ul>

# %% [markdown]
# ![Breedog.png](attachment:Breedog.png)

# %% [markdown]
# ### What is the most popular Dog Stage
#
# Some Dogs are Doggos, some are puppers, and other may even be flooter, I gonna compare what is the most popular dog stage, I could understand whats is the most popular stage of dog are a suffix of dog and its using like as DoggoSpeak.
# <ul>
#     <li>The most popular stage was Pupper.</li>
#     <li>The doggo, puppo and floofer referred to a most common lexical using in a post on twitter but all of them are using commonly </li>
#     </ul>

# %% [markdown]
# ![cake.png](attachment:cake.png)

# %% [markdown]
# ### What is the trend in the favorities and retweets over time?
#
# This trend was increasing, probably favorites and retweets increasing with the account a long time meanwhile the account became more popular.
# <ul>
#     <li>In the chart below we can show upward trend for both retweets and favorites </li>
#     <li>I noticed that increase the number of favorites when compared between to retweets as well as several large outliers in favorites for extremely popular tweets </li>
#     </ul>

# %% [markdown]
# ![retweets_favorites.png](attachment:retweets_favorites.png)
